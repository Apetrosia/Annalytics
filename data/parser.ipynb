# %% [markdown]
# Перевод в json

# %%
import pandas as pd

# Прочитать CSV-файл
df = pd.read_csv('Steam Trends 2023.csv', sep=';', encoding='utf-8')
df.shape
# Out:
# (65111, 14)

# %%
# Сохранить содержимое как JSON
df.to_json('Steam Trends 2023.json', orient='records', force_ascii=False)
